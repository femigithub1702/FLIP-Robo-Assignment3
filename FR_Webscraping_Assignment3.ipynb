# %% [markdown]
# # 1) # Write a python program which searches all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user.  For e.g. If user input is ‘guitar’. Then search for guitars

# %%
# Importing  Libraries 
import numpy as np
import pandas as pd
from  selenium import webdriver
from time import sleep
import warnings
warnings.filterwarnings('ignore')
import time
import string
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

path =r"C:\Users\Femina\Downloads\chromedriver_win32\chromedriver.exe "
driver=webdriver.Chrome(path)
my_page=driver.get('https://www.amazon.in')

# %%
Task2=driver.find_element_by_xpath("//div[@class='nav-search-field ']/input")
Task2.send_keys('Sunglasses')
time.sleep(5)

# %%
time.sleep(5)
Task4=driver.find_element_by_xpath("//div[@class='nav-right']")
Task4.click()
time.sleep(5)

# %% [markdown]
# # 2)  -In the above question, now scrape the following details of each product listed in first 3 pagesof your search results and save it in a data frame and csv. In case if any product vertical hasless than 3 pages in search results then scrape all the products available under that productvertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details"and “Product URL”. In case, if any of the details are missing for any of the product thenreplace it by “-“.

# %%
#Creating empty list
Brand_Name = []
Name_of_the_Product = []
Rating  = []
Total_Ratings  = []
Price  = []
Return_Exchange  = []
Expected_Delivery  = []
Availability = []
Other_Details = []
Product_URL = []

# %%
Task1 = driver.find_elements_by_xpath("//span[@class='a-size-base-plus a-color-base']")

for hy in Task1[5:21]:
        se = hy.text
        Brand_Name.append(se)

for gh in Task1[33:64]:
            se1 = gh.text
            Brand_Name.append(se1)

# %%
start_page=1
end_page=3
    
    
for page in range(start_page,end_page+1):
        
        Task1 = driver.find_elements_by_xpath("//span[@class='a-size-base-plus a-color-base']")

        for hy in Task1[5:21]:
            se = hy.text
            Brand_Name.append(se)
        time.sleep(2)

        for gh in Task1[33:64]:
            se1 = gh.text
            Brand_Name.append(se1)
            
        Task1 = driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a/span")

        for hy in Task1[5:21]:
            se = hy.text
            Name_of_the_Product.append(se)
        time.sleep(3)

        for gh in Task1[33:64]:
            se1 = gh.text
            Name_of_the_Product.append(se1)

        urls1=[i.get_attribute("href")for i in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")]
        for yu in urls1[5:21]:
            Product_URL.append(yu)
            
        time.sleep(3)
    
        for ui in urls1[33:64]:
            Product_URL.append(ui)

    
            
        time.sleep(3)
        nxt_button1=driver.find_element_by_xpath("//a[text()='Next']").click()

# %%
print(len(Product_URL))
print(len(Brand_Name))
print(len(Name_of_the_Product))
# Out:
# 121
# 99
# 121

# %%
for url in Product_URL:
    driver.get(url)

        
        
    try:
        Task3 = driver.find_element_by_xpath("//div[@id='averageCustomerReviews']/span[3]/a/span").text
    
        Total_Ratings.append(Task3)
    except NoSuchElementException: 
        Total_Ratings.append('--')
        
    try:
        Task3 = driver.find_element_by_xpath("//span[@id ='priceblock_ourprice'] | //span[@id ='priceblock_saleprice'] |  //span[@id ='priceblock_dealprice']").text
    
        Price.append(Task3)
    except NoSuchElementException: 
        Price.append('--')
        
    try:
        Task3 = driver.find_element_by_xpath("//div/span/div[2]/a[@class ='a-size-small a-link-normal a-text-normal']").text
    
        Return_Exchange.append(Task3)
    except NoSuchElementException: 
        Return_Exchange.append('--')
        
    try:
        Task3 = driver.find_element_by_xpath("//div[@id='ddmDeliveryMessage']/b").text
    
        Expected_Delivery.append(Task3)
    except NoSuchElementException: 
        Expected_Delivery.append('--')
        
        
    try:
        Task3 = driver.find_element_by_xpath("//input[@id='add-to-cart-button']")
    
        Availability.append('Available')
    except NoSuchElementException: 
        Availability.append('Not Available')
        
    try:
        Task3 = driver.find_element_by_xpath("//ul[@class='a-unordered-list a-vertical a-spacing-mini']").text
    
        Other_Details.append(Task3)
    except NoSuchElementException: 
        Other_Details.append('--')
        
    try:                  
        rate=driver.find_element_by_xpath("//span[@id='acrCustomerReviewText']")
        rate.click()                                                      
        rating=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")#locating the rating
        Rating.append(rating.text)#appending the ratings in Ratings list
        
    except NoSuchElementException   as e:
        Rating.append("NO rating")#appending the No rating if no rating is there

# %%
Sunglasses = pd.DataFrame({'Brand_Name' : Brand_Name[0:99], 'Name of the Product': Name_of_the_Product[0:99] ,'Rating' :Rating[0:99] ,'Total_Ratings' :Total_Ratings[0:99] ,'Price' :Price[0:99] ,'Return_Exchange' :Return_Exchange[0:99] ,'Expected_Delivery': Expected_Delivery[0:99] ,'Availability' :Availability[0:99] , 'Other_Details':Other_Details[0:99] ,'Product_URL': Product_URL[0:99]})
Sunglasses
# Out:
#    Brand_Name                                Name of the Product  \
# 0    Fastrack  Men Square Sunglasses Black Frame Black Lens (...
# 1    Fastrack  UV Protected Wayfarer Men's Sunglasses - (P425...
# 2       NUVeW  Mirrored Cat eye Sunglasses For Women - (Color...
# 3   ROYAL SON                    Unisex Adult Aviator Sunglasses
# 4    Fastrack        Men Pilot Sunglasses Black Frame Brown Lens
# ..        ...                                                ...
# 94   Fastrack  Blue Sports Sunglasses for Driving, Biking, Cy...
# 95      CREEK     Men's Black Sunglasses-56 (CBARKLEYC1EL1012-L)
# 96      CREEK  Metal Body Square Inspired from Kabir Singh Su...
# 97   CREATURE       Men Square Sunglasses Black Frame Black Lens
# 98  ROYAL SON  Set of Jazz Manak Inspired Black Sunglasses wi...
#
#           Rating  Total_Ratings      Price             Return_Exchange  \
# 0     4 out of 5  9,048 ratings    ₹513.00             10 Days Returns
# 1   4.1 out of 5    409 ratings    ₹519.00             10 Days Returns
# 2   4.4 out of 5    315 ratings    ₹425.00             10 Days Returns
# 3   3.7 out of 5  2,184 ratings    ₹375.00             10 Days Returns
# 4     4 out of 5  2,917 ratings    ₹647.00             10 Days Returns
# ..           ...            ...        ...                         ...
# 94  3.8 out of 5     13 ratings    ₹549.00             10 Days Returns
# 95    5 out of 5      2 ratings  ₹1,361.00             30 Days Returns
# 96  4.6 out of 5     16 ratings    ₹399.00             10 Days Returns
# 97  4.1 out of 5    380 ratings    ₹830.00             10 Days Returns
# 98    3 out of 5      7 ratings    ₹399.00  30 Days Returns & Exchange
#
#     Expected_Delivery Availability  \
# 0   Wednesday, Aug 25    Available
# 1    Thursday, Aug 26    Available
# 2   Wednesday, Aug 25    Available
# 3   Wednesday, Aug 25    Available
# 4   Wednesday, Aug 25    Available
# ..                ...          ...
# 94  Wednesday, Aug 25    Available
# 95   Saturday, Aug 28    Available
# 96   Thursday, Aug 26    Available
# 97  Wednesday, Aug 25    Available
# 98   Thursday, Aug 26    Available
#
#                                         Other_Details  \
# 0   Size Map: Small ; Lens Material: Polycarbonate...
# 1   Size Map: Large\nFrame size: Lens width - 55 m...
# 2   Imported Stylish Cateye Sunglasses\n100% UV Pr...
# 3   HIGH QUALITY MATERIALS – Royal Son sunglasses ...
# 4   Model: P358BK2, Part Number:P358BK2\nFrame Col...
# ..                                                ...
# 94  OPTIMUM GIFT FOR MANY OCCASIONS— Great fashion...
# 95  Polarized\nLarge\nSunglasses\nTarget gender: male
# 96  Branded Smooth Leg Covers Lightweight Square K...
# 97  Model: P425BK3, Part Number:P425BK3\nFrame Col...
# 98                                                 --
#
#                                           Product_URL
# 0   https://www.amazon.in/Fastrack-protected-Sungl...
# 1   https://www.amazon.in/Fastrack-Protected-Wayfa...
# 2   https://www.amazon.in/NuVew-Protected-Sunglass...
# 3   https://www.amazon.in/Protected-Aviator-Unisex...
# 4   https://www.amazon.in/Fastrack-protected-Sungl...
# ..                                                ...
# 94  https://www.amazon.in/Peter-Jones-Sunglasses-D...
# 95  https://www.amazon.in/Eyewearlabs-Mens-Black-S...
# 96  https://www.amazon.in/EYELAND-Metal-Square-Ins...
# 97  https://www.amazon.in/Fastrack-Protected-Wayfa...
# 98  https://www.amazon.in/Davidson-Manak-Inspired-...
#
# [99 rows x 10 columns]

# %% [markdown]
# # Q3.Python program to access the search bar and search button on images.google.com

# %% [markdown]
# Scrape 100 images each for keywords
# 1.‘fruits’
# 2. ‘cars’
# 3. ‘Machine Learning’.

# %%
#Importing al the required Libraries
import selenium
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException

# %%
#get the web page with given url
driver = webdriver.Chrome(r"C:\Users\Femina\Downloads\chromedriver_win32\chromedriver.exe ")
url = "https://images.google.com/"
urls = []    #image urls to download
data = []
search_item = ["fruits", "cars", "Machine Learning"]
for item in search_item:
    driver.get(url)  #google search for items
    time.sleep(5)
    search_bar = driver.find_element_by_tag_name("input") #finding search bar
    
    search_bar.send_keys(str(item))      #send search item
    
    search_button =driver.find_element_by_xpath("//button[@class='Tg7LZd']").click() #lets click on search button
    
    # scroll the page in order to generate more images on the website
    for _ in range(500):
        driver.execute_script("window.scrollBy(0,100)")
        
        imgs = driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
    img_url = []
    for image in imgs:
        source = image.get_attribute('src')
        if source is not None:
                if(source[0:4] == 'http'):
                    img_url.append(source)
    for i in img_url[:100]:
        urls.append(i)
                    
for i in range(len(urls)):
    if i >= 300:
        break
    print("Downloading {0} of {1} images" .format(i, 300))
    response= requests.get(urls[i])

    file = open(r"C:\Users\Femina\Desktop\Google images\images"+str(i)+".jpg", "wb")

    file.write(response.content)
# Out:
# Downloading 0 of 300 images
# Downloading 1 of 300 images
# Downloading 2 of 300 images
# Downloading 3 of 300 images
# Downloading 4 of 300 images
# Downloading 5 of 300 images
# Downloading 6 of 300 images
# Downloading 7 of 300 images
# Downloading 8 of 300 images
# Downloading 9 of 300 images
# Downloading 10 of 300 images
# Downloading 11 of 300 images
# Downloading 12 of 300 images
# Downloading 13 of 300 images
# Downloading 14 of 300 images
# Downloading 15 of 300 images
# Downloading 16 of 300 images
# Downloading 17 of 300 images
# Downloading 18 of 300 images
# Downloading 19 of 300 images
# Downloading 20 of 300 images
# Downloading 21 of 300 images
# Downloading 22 of 300 images
# Downloading 23 of 300 images
# Downloading 24 of 300 images
# Downloading 25 of 300 images
# Downloading 26 of 300 images
# Downloading 27 of 300 images
# Downloading 28 of 300 images
# Downloading 29 of 300 images
# Downloading 30 of 300 images
# Downloading 31 of 300 images
# Downloading 32 of 300 images
# Downloading 33 of 300 images
# Downloading 34 of 300 images
# Downloading 35 of 300 images
# Downloading 36 of 300 images
# Downloading 37 of 300 images
# Downloading 38 of 300 images
# Downloading 39 of 300 images
# Downloading 40 of 300 images
# Downloading 41 of 300 images
# Downloading 42 of 300 images
# Downloading 43 of 300 images
# Downloading 44 of 300 images
# Downloading 45 of 300 images
# Downloading 46 of 300 images
# Downloading 47 of 300 images
# Downloading 48 of 300 images
# Downloading 49 of 300 images
# Downloading 50 of 300 images
# Downloading 51 of 300 images
# Downloading 52 of 300 images
# Downloading 53 of 300 images
# Downloading 54 of 300 images
# Downloading 55 of 300 images
# Downloading 56 of 300 images
# Downloading 57 of 300 images
# Downloading 58 of 300 images
# Downloading 59 of 300 images
# Downloading 60 of 300 images
# Downloading 61 of 300 images
# Downloading 62 of 300 images
# Downloading 63 of 300 images
# Downloading 64 of 300 images
# Downloading 65 of 300 images
# Downloading 66 of 300 images
# Downloading 67 of 300 images
# Downloading 68 of 300 images
# Downloading 69 of 300 images
# Downloading 70 of 300 images
# Downloading 71 of 300 images
# Downloading 72 of 300 images
# Downloading 73 of 300 images
# Downloading 74 of 300 images
# Downloading 75 of 300 images
# Downloading 76 of 300 images
# Downloading 77 of 300 images
# Downloading 78 of 300 images
# Downloading 79 of 300 images
# Downloading 80 of 300 images
# Downloading 81 of 300 images
# Downloading 82 of 300 images
# Downloading 83 of 300 images
# Downloading 84 of 300 images
# Downloading 85 of 300 images
# Downloading 86 of 300 images
# Downloading 87 of 300 images
# Downloading 88 of 300 images
# Downloading 89 of 300 images
# Downloading 90 of 300 images
# Downloading 91 of 300 images
# Downloading 92 of 300 images
# Downloading 93 of 300 images
# Downloading 94 of 300 images
# Downloading 95 of 300 images
# Downloading 96 of 300 images
# Downloading 97 of 300 images
# Downloading 98 of 300 images
# Downloading 99 of 300 images
# Downloading 100 of 300 images
# Downloading 101 of 300 images
# Downloading 102 of 300 images
# Downloading 103 of 300 images
# Downloading 104 of 300 images
# Downloading 105 of 300 images
# Downloading 106 of 300 images
# Downloading 107 of 300 images
# Downloading 108 of 300 images
# Downloading 109 of 300 images
# Downloading 110 of 300 images
# Downloading 111 of 300 images
# Downloading 112 of 300 images
# Downloading 113 of 300 images
# Downloading 114 of 300 images
# Downloading 115 of 300 images
# Downloading 116 of 300 images
# Downloading 117 of 300 images
# Downloading 118 of 300 images
# Downloading 119 of 300 images
# Downloading 120 of 300 images
# Downloading 121 of 300 images
# Downloading 122 of 300 images
# Downloading 123 of 300 images
# Downloading 124 of 300 images
# Downloading 125 of 300 images
# Downloading 126 of 300 images
# Downloading 127 of 300 images
# Downloading 128 of 300 images
# Downloading 129 of 300 images
# Downloading 130 of 300 images
# Downloading 131 of 300 images
# Downloading 132 of 300 images
# Downloading 133 of 300 images
# Downloading 134 of 300 images
# Downloading 135 of 300 images
# Downloading 136 of 300 images
# Downloading 137 of 300 images
# Downloading 138 of 300 images
# Downloading 139 of 300 images
# Downloading 140 of 300 images
# Downloading 141 of 300 images
# Downloading 142 of 300 images
# Downloading 143 of 300 images
# Downloading 144 of 300 images
# Downloading 145 of 300 images
# Downloading 146 of 300 images
# Downloading 147 of 300 images
# Downloading 148 of 300 images
# Downloading 149 of 300 images
# Downloading 150 of 300 images
# Downloading 151 of 300 images
# Downloading 152 of 300 images
# Downloading 153 of 300 images
# Downloading 154 of 300 images
# Downloading 155 of 300 images
# Downloading 156 of 300 images
# Downloading 157 of 300 images
# Downloading 158 of 300 images
# Downloading 159 of 300 images
# Downloading 160 of 300 images
# Downloading 161 of 300 images
# Downloading 162 of 300 images
# Downloading 163 of 300 images
# Downloading 164 of 300 images
# Downloading 165 of 300 images
# Downloading 166 of 300 images
# Downloading 167 of 300 images
# Downloading 168 of 300 images
# Downloading 169 of 300 images
# Downloading 170 of 300 images
# Downloading 171 of 300 images
# Downloading 172 of 300 images
# Downloading 173 of 300 images
# Downloading 174 of 300 images
# Downloading 175 of 300 images
# Downloading 176 of 300 images
# Downloading 177 of 300 images
# Downloading 178 of 300 images
# Downloading 179 of 300 images
# Downloading 180 of 300 images
# Downloading 181 of 300 images
# Downloading 182 of 300 images
# Downloading 183 of 300 images
# Downloading 184 of 300 images
# Downloading 185 of 300 images
# Downloading 186 of 300 images
# Downloading 187 of 300 images
# Downloading 188 of 300 images
# Downloading 189 of 300 images
# Downloading 190 of 300 images
# Downloading 191 of 300 images
# Downloading 192 of 300 images
# Downloading 193 of 300 images
# Downloading 194 of 300 images
# Downloading 195 of 300 images
# Downloading 196 of 300 images
# Downloading 197 of 300 images
# Downloading 198 of 300 images
# Downloading 199 of 300 images
# Downloading 200 of 300 images
# Downloading 201 of 300 images
# Downloading 202 of 300 images
# Downloading 203 of 300 images
# Downloading 204 of 300 images
# Downloading 205 of 300 images
# Downloading 206 of 300 images
# Downloading 207 of 300 images
# Downloading 208 of 300 images
# Downloading 209 of 300 images
# Downloading 210 of 300 images
# Downloading 211 of 300 images
# Downloading 212 of 300 images
# Downloading 213 of 300 images
# Downloading 214 of 300 images
# Downloading 215 of 300 images
# Downloading 216 of 300 images
# Downloading 217 of 300 images
# Downloading 218 of 300 images
# Downloading 219 of 300 images
# Downloading 220 of 300 images
# Downloading 221 of 300 images
# Downloading 222 of 300 images
# Downloading 223 of 300 images
# Downloading 224 of 300 images
# Downloading 225 of 300 images
# Downloading 226 of 300 images
# Downloading 227 of 300 images
# Downloading 228 of 300 images
# Downloading 229 of 300 images
# Downloading 230 of 300 images
# Downloading 231 of 300 images
# Downloading 232 of 300 images
# Downloading 233 of 300 images
# Downloading 234 of 300 images
# Downloading 235 of 300 images
# Downloading 236 of 300 images
# Downloading 237 of 300 images
# Downloading 238 of 300 images
# Downloading 239 of 300 images
# Downloading 240 of 300 images
# Downloading 241 of 300 images
# Downloading 242 of 300 images
# Downloading 243 of 300 images
# Downloading 244 of 300 images
# Downloading 245 of 300 images
# Downloading 246 of 300 images
# Downloading 247 of 300 images
# Downloading 248 of 300 images
# Downloading 249 of 300 images
# Downloading 250 of 300 images
# Downloading 251 of 300 images
# Downloading 252 of 300 images
# Downloading 253 of 300 images
# Downloading 254 of 300 images
# Downloading 255 of 300 images
# Downloading 256 of 300 images
# Downloading 257 of 300 images
# Downloading 258 of 300 images
# Downloading 259 of 300 images
# Downloading 260 of 300 images
# Downloading 261 of 300 images
# Downloading 262 of 300 images
# Downloading 263 of 300 images
# Downloading 264 of 300 images
# Downloading 265 of 300 images
# Downloading 266 of 300 images
# Downloading 267 of 300 images
# Downloading 268 of 300 images
# Downloading 269 of 300 images
# Downloading 270 of 300 images
# Downloading 271 of 300 images
# Downloading 272 of 300 images
# Downloading 273 of 300 images
# Downloading 274 of 300 images
# Downloading 275 of 300 images
# Downloading 276 of 300 images
# Downloading 277 of 300 images
# Downloading 278 of 300 images
# Downloading 279 of 300 images
# Downloading 280 of 300 images
# Downloading 281 of 300 images
# Downloading 282 of 300 images
# Downloading 283 of 300 images
# Downloading 284 of 300 images
# Downloading 285 of 300 images
# Downloading 286 of 300 images
# Downloading 287 of 300 images
# Downloading 288 of 300 images
# Downloading 289 of 300 images
# Downloading 290 of 300 images
# Downloading 291 of 300 images
# Downloading 292 of 300 images
# Downloading 293 of 300 images
# Downloading 294 of 300 images
# Downloading 295 of 300 images
# Downloading 296 of 300 images
# Downloading 297 of 300 images
# Downloading 298 of 300 images
# Downloading 299 of 300 images

# %% [markdown]
# # Que- 4  Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver = webdriver.Chrome(r"C:\Users\Femina\Downloads\chromedriver_win32\chromedriver.exe ")
#get the web page with given url
url = "https://www.flipkart.com/"
driver.get(url)
time.sleep(3)

cancle_btn = driver.find_element_by_xpath("//div[@class='_2QfC02']//button").click()
#giving inputs to search bar
serch_bar = driver.find_element_by_xpath("//div[@class='_3OO5Xc']//input")
serch_bar.send_keys("smartphone")

srch_btn = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
srch_btn.click()
time.sleep(5)

# %%
#fetching urls of every smartphone
urls = []
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    urls.append(i.get_attribute("href"))

#fetching required data
brand_names = []
name = []
color = []
RAM = []
storage = []
prim_cam = []
sec_cam = []
Display_size = []
display_resolution = []
processor = []
processor_core = []
battery_cap = []
prices = []
product_url = []
#fetching Battery capacity
for i in driver.find_elements_by_xpath("//div[@class='fMghEO']"):
    try:
        bat_cap = driver.find_element_by_xpath("//ul[@class='_1xgFaf']//li[4]")
        battery_cap.append(bat_cap.text)
    except NoSuchElementException:
        battery_cap.append('-')
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    #fetching brand names
    try:
        br_name = driver.find_element_by_xpath("/html/body/div/div/div[3]/div[1]/div[2]/div[1]/div[1]/div/div[4]/a")
        brand_names.append(br_name.text.replace('Mobiles',''))
    except NoSuchElementException:
        brand_names.append('-')
    #fetching smartphone names
    try:
        smt_name = driver.find_element_by_xpath("//h1[@class='yhB1nd']//span")
        name.append(smt_name.text)
    except NoSuchElementException:
        name.append('-')
    
    #fetching colors of smartphone
    try:
        clr = driver.find_element_by_xpath("//table[@class='_14cfVK']//tr[4]//td[2]")
        color.append(clr.text)
    except NoSuchElementException:
        color.append('-')
    time.sleep(2)
    #readmore button
    try:
        read_more_btn = driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    except NoSuchElementException:
        pass
    time.sleep(3)
    
    #fetching Display size
    try:
        disp_size = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[1]//td[2]")
        Display_size.append(disp_size.text)
    except NoSuchElementException:
        Display_size.append
        
    #fetching display_resolution
    try:
        disp_res = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[2]//td[2]")
        display_resolution.append(disp_res.text)
    except NoSuchElementException:
        display_resolution.append('-')
        
    #fetching processor info
    try:
        pro = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[2]//td[2]")
        processor.append(pro.text)
    except NoSuchElementException:
        processor.append('-')
    #ferching processor core info
    try:
        pro_core = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[3]//td[2]")
        processor_core.append(pro_core.text)
    except NoSuchElementException:
        processor_core.append('-')
    #fetching storage/ROM
    try:
        rom = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[1]//td[2]")
        storage.append(rom.text)
    except NoSuchElementException:
        storage.append('-')
    #fetching RAM info
    try:
        ram = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[2]//td[2]")
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append('-')
    time.sleep(2)
    
    #fetching primary camera info
    try:
        p_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[2]//td[2]")
        prim_cam.append(p_cam.text)
    except NoSuchElementException:
        prim_cam.append('-')
    #fetching secondary camera info
    try:
        s_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[5]//td[2]")
        sec_cam.append(s_cam.text)
    except NoSuchElementException:
        sec_cam.append('-')
    
    
   
    #fetching price of smartphone
    try:
        price = driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        prices.append(price.text.replace('₹','Rs. '))
    except NoSuchElementException:
        prices.append('-')
    
    
#creating dataframe
data = list(zip(brand_names,name,color,RAM,storage,prim_cam,sec_cam,Display_size,display_resolution,processor,processor_core,battery_cap,prices,urls))
df = pd.DataFrame(data, columns = ["Brand Name","Smartphone Name","color","RAM","Storage/ROM","primary Camera","Secondary Camera","Display size","Display Resolution","Processor","Processor-core","Battery Capacity","Price","Product url"])

#passing dataframe to csv file
df.to_csv(r"C:\Users\Femina\Desktop\data science\flipkart_smartphones.csv")
#print dataframe
df
# Out:
#    Brand Name                                  Smartphone Name  \
# 0     realme        realme C21 (Cross Blue, 64 GB)  (4 GB RAM)
# 1      REDMI      REDMI 9i (Midnight Black, 64 GB)  (4 GB RAM)
# 2     realme       realme C21 (Cross Black, 32 GB)  (3 GB RAM)
# 3     I Kall          I Kall Z1 (Dark Blue, 32 GB)  (4 GB RAM)
# 4     realme       realme C21 (Cross Black, 64 GB)  (4 GB RAM)
# 5     realme        realme C21 (Cross Blue, 32 GB)  (3 GB RAM)
# 6     realme     realme C25s (Watery Grey, 128 GB)  (4 GB RAM)
# 7     I Kall               I Kall Z2 (Blue, 32 GB)  (4 GB RAM)
# 8     realme     realme C25s (Watery Blue, 128 GB)  (4 GB RAM)
# 9      REDMI            REDMI 9i (Sea Blue, 64 GB)  (4 GB RAM)
# 10     REDMI     REDMI 9 Prime (Space Blue, 64 GB)  (4 GB RAM)
# 11     REDMI        REDMI 9i (Nature Green, 64 GB)  (4 GB RAM)
# 12     REDMI    REDMI 9 Prime (Matte Black, 64 GB)  (4 GB RAM)
# 13    realme         realme C20 (Cool Grey, 32 GB)  (2 GB RAM)
# 14    realme         realme C20 (Cool Blue, 32 GB)  (2 GB RAM)
# 15    realme    realme C11 2021 (Cool Grey, 32 GB)  (2 GB RAM)
# 16    realme    realme C11 2021 (Cool Blue, 32 GB)  (2 GB RAM)
# 17      POCO            POCO M3 (Cool Blue, 64 GB)  (4 GB RAM)
# 18     REDMI   REDMI 9 Power (Blazing Blue, 64 GB)  (4 GB RAM)
# 19      POCO          POCO C3 (Arctic Blue, 64 GB)  (4 GB RAM)
# 20      POCO            POCO M3 (Cool Blue, 64 GB)  (6 GB RAM)
# 21      POCO          POCO M3 (Power Black, 64 GB)  (4 GB RAM)
# 22      POCO               POCO M3 (Yellow, 64 GB)  (4 GB RAM)
# 23      POCO          POCO C3 (Matte Black, 32 GB)  (3 GB RAM)
#
#              color                 RAM Storage/ROM          primary Camera  \
# 0       Cross Blue                4 GB       64 GB        13MP + 2MP + 2MP
# 1   Midnight Black                4 GB       64 GB        13MP Rear Camera
# 2      Cross Black                3 GB       32 GB        13MP + 2MP + 2MP
# 3        Dark Blue                4 GB       32 GB         8MP Rear Camera
# 4      Cross Black                4 GB       64 GB        13MP + 2MP + 2MP
# 5       Cross Blue                3 GB       32 GB        13MP + 2MP + 2MP
# 6      Watery Grey                4 GB      128 GB        13MP + 2MP + 2MP
# 7             Blue                4 GB       32 GB         8MP Rear Camera
# 8      Watery Blue                4 GB      128 GB        13MP + 2MP + 2MP
# 9         Sea Blue                4 GB       64 GB        13MP Rear Camera
# 10      Space Blue                4 GB       64 GB  13MP + 8MP + 5MP + 2MP
# 11    Nature Green                4 GB       64 GB        13MP Rear Camera
# 12     Matte Black                4 GB       64 GB  13MP + 8MP + 5MP + 2MP
# 13       Cool Grey  MediaTek Helio G35  Android 10                    2 GB
# 14       Cool Blue  MediaTek Helio G35  Android 10                    2 GB
# 15       Cool Grey                2 GB       32 GB         8MP Rear Camera
# 16       Cool Blue                2 GB       32 GB         8MP Rear Camera
# 17       Cool Blue                4 GB       64 GB        48MP + 2MP + 2MP
# 18    Blazing Blue                4 GB       64 GB  48MP + 8MP + 2MP + 2MP
# 19     Arctic Blue                4 GB       64 GB        13MP + 2MP + 2MP
# 20       Cool Blue                6 GB       64 GB        48MP + 2MP + 2MP
# 21     Power Black                4 GB       64 GB        48MP + 2MP + 2MP
# 22          Yellow                4 GB       64 GB        48MP + 2MP + 2MP
# 23     Matte Black                3 GB       32 GB        13MP + 2MP + 2MP
#
#     Secondary Camera                                       Display size  \
# 0   5MP Front Camera                                16.51 cm (6.5 inch)
# 1   5MP Front Camera                               16.59 cm (6.53 inch)
# 2   5MP Front Camera                                16.51 cm (6.5 inch)
# 3   5MP Front Camera                               13.84 cm (5.45 inch)
# 4   5MP Front Camera                                16.51 cm (6.5 inch)
# 5   5MP Front Camera                                16.51 cm (6.5 inch)
# 6   8MP Front Camera                                16.51 cm (6.5 inch)
# 7   5MP Front Camera                                15.9 cm (6.26 inch)
# 8   8MP Front Camera                                16.51 cm (6.5 inch)
# 9   5MP Front Camera                               16.59 cm (6.53 inch)
# 10  8MP Front Camera                               16.59 cm (6.53 inch)
# 11  5MP Front Camera                               16.59 cm (6.53 inch)
# 12  8MP Front Camera                               16.59 cm (6.53 inch)
# 13    Dedicated Slot  Handset, Adapter (5V/2A), USB Cable, SIM Card ...
# 14    Dedicated Slot  Handset, Adapter (5V/2A), USB Cable, SIM Card ...
# 15  5MP Front Camera                                16.51 cm (6.5 inch)
# 16  5MP Front Camera                                16.51 cm (6.5 inch)
# 17  8MP Front Camera                               16.59 cm (6.53 inch)
# 18  8MP Front Camera                               16.59 cm (6.53 inch)
# 19  5MP Front Camera                               16.59 cm (6.53 inch)
# 20  8MP Front Camera                               16.59 cm (6.53 inch)
# 21  8MP Front Camera                               16.59 cm (6.53 inch)
# 22  8MP Front Camera                               16.59 cm (6.53 inch)
# 23  5MP Front Camera                               16.59 cm (6.53 inch)
#
#     Display Resolution                Processor Processor-core  \
# 0    1600 x 720 Pixels       MediaTek Helio G35      Octa Core
# 1    1600 x 720 Pixels       MediaTek Helio G25      Octa Core
# 2    1600 x 720 Pixels       MediaTek Helio G35      Octa Core
# 3     480 x 960$$pixel                Quad Core        1.3 GHz
# 4    1600 x 720 Pixels       MediaTek Helio G35      Octa Core
# 5    1600 x 720 Pixels       MediaTek Helio G35      Octa Core
# 6    1600 x 720 Pixels       MediaTek Helio G85      Octa Core
# 7    480 x 1014$$pixel                Quad Core        1.3 GHz
# 8    1600 x 720 Pixels       MediaTek Helio G85      Octa Core
# 9    1600 x 720 Pixels       MediaTek Helio G25      Octa Core
# 10  2340 x 1080 Pixels       MediaTek Helio G80      Octa Core
# 11   1600 x 720 Pixels       MediaTek Helio G25      Octa Core
# 12  2340 x 1080 Pixels       MediaTek Helio G80      Octa Core
# 13   RMX3063 / RMX3061        1600 x 720 Pixels            HD+
# 14   RMX3063 / RMX3061        1600 x 720 Pixels            HD+
# 15   1600 x 720 Pixels                Octa-core      Octa Core
# 16   1600 x 720 Pixels                Octa-core      Octa Core
# 17  2340 x 1080 Pixels  Qualcomm Snapdragon 662      Octa Core
# 18  2340 x 1080$$pixel  Qualcomm Snapdragon 662      Octa Core
# 19   1600 x 720 Pixels       Mediatek Helio G35      Octa Core
# 20  2340 x 1080 Pixels  Qualcomm Snapdragon 662      Octa Core
# 21  2340 x 1080 Pixels  Qualcomm Snapdragon 662      Octa Core
# 22  2340 x 1080 Pixels  Qualcomm Snapdragon 662      Octa Core
# 23   1600 x 720 Pixels       Mediatek Helio G35      Octa Core
#
#     Battery Capacity       Price  \
# 0   5000 mAh Battery   Rs. 9,499
# 1   5000 mAh Battery   Rs. 8,499
# 2   5000 mAh Battery   Rs. 8,499
# 3   5000 mAh Battery   Rs. 5,499
# 4   5000 mAh Battery   Rs. 9,499
# 5   5000 mAh Battery   Rs. 8,499
# 6   5000 mAh Battery  Rs. 11,499
# 7   5000 mAh Battery   Rs. 6,599
# 8   5000 mAh Battery  Rs. 11,499
# 9   5000 mAh Battery   Rs. 8,499
# 10  5000 mAh Battery   Rs. 9,999
# 11  5000 mAh Battery   Rs. 8,499
# 12  5000 mAh Battery  Rs. 11,972
# 13  5000 mAh Battery   Rs. 7,499
# 14  5000 mAh Battery   Rs. 7,499
# 15  5000 mAh Battery   Rs. 6,999
# 16  5000 mAh Battery   Rs. 6,999
# 17  5000 mAh Battery  Rs. 10,499
# 18  5000 mAh Battery  Rs. 10,999
# 19  5000 mAh Battery   Rs. 8,499
# 20  5000 mAh Battery  Rs. 11,999
# 21  5000 mAh Battery  Rs. 10,499
# 22  5000 mAh Battery  Rs. 10,499
# 23  5000 mAh Battery   Rs. 7,499
#
#                                           Product url
# 0   https://www.flipkart.com/realme-c21-cross-blue...
# 1   https://www.flipkart.com/redmi-9i-midnight-bla...
# 2   https://www.flipkart.com/realme-c21-cross-blac...
# 3   https://www.flipkart.com/kall-z1-dark-blue-32-...
# 4   https://www.flipkart.com/realme-c21-cross-blac...
# 5   https://www.flipkart.com/realme-c21-cross-blue...
# 6   https://www.flipkart.com/realme-c25s-watery-gr...
# 7   https://www.flipkart.com/kall-z2-blue-32-gb/p/...
# 8   https://www.flipkart.com/realme-c25s-watery-bl...
# 9   https://www.flipkart.com/redmi-9i-sea-blue-64-...
# 10  https://www.flipkart.com/redmi-9-prime-space-b...
# 11  https://www.flipkart.com/redmi-9i-nature-green...
# 12  https://www.flipkart.com/redmi-9-prime-matte-b...
# 13  https://www.flipkart.com/realme-c20-cool-grey-...
# 14  https://www.flipkart.com/realme-c20-cool-blue-...
# 15  https://www.flipkart.com/realme-c11-2021-cool-...
# 16  https://www.flipkart.com/realme-c11-2021-cool-...
# 17  https://www.flipkart.com/poco-m3-cool-blue-64-...
# 18  https://www.flipkart.com/redmi-9-power-blazing...
# 19  https://www.flipkart.com/poco-c3-arctic-blue-6...
# 20  https://www.flipkart.com/poco-m3-cool-blue-64-...
# 21  https://www.flipkart.com/poco-m3-power-black-6...
# 22  https://www.flipkart.com/poco-m3-yellow-64-gb/...
# 23  https://www.flipkart.com/poco-c3-matte-black-3...

# %% [markdown]
# # Q.No.5 Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
driver = webdriver.Chrome(r"C:\Users\Femina\Downloads\chromedriver_win32\chromedriver.exe ")

#get the web page with given url
url = "https://www.google.com/maps/@16.4721906,74.435855,14z"
driver.get(url)

srch_box = driver.find_element_by_class_name("tactile-searchbox-input")  #fetching search bar

place = str(input("Enter place name, you want to search: "))  #Entering inputs to search for location

srch_box.send_keys(place)    

submit = driver.find_element_by_class_name("searchbox-searchbutton").click()  #search button

current_url = driver.current_url   #coordinates are presents in URL so fetch current url

import re

lat = re.findall('(\d+(\.\d*)?)', current_url)[0]   #fetching latitude
long = re.findall('(\d+(\.\d*)?)', current_url)[1]     #fetching longitude

print("coordinates for the searched location,", place + " are: ")
print("Latitude :", lat[0])
print("Longitude :", long[0])
# Out:
# Enter place name, you want to search: Kerala
# coordinates for the searched location, Kerala are:
# Latitude : 16.4721906
# Longitude : 74.435855

# %% [markdown]
# # 6) Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 – September 20) from trak.in.

# %%
# Importing  Libraries 
import numpy as np
import pandas as pd
from  selenium import webdriver
from time import sleep
import warnings
warnings.filterwarnings('ignore')
import time
import string
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

path =r"C:\Users\Femina\Downloads\chromedriver_win32\chromedriver.exe "
driver=webdriver.Chrome(path)
my_page=driver.get('https://trak.in/india-startup-funding-investment-2015/') #For scraping data from trak.in

# %%
#Creating empty list
Date = []
Start_up_name = []
Industry = []
Sub_vertical =[]
city =[]
Invester_name =[]
Investment_type =[]
amount = []

# %%
        Task1 = driver.find_elements_by_xpath("//td[@class='column-2']")

        for hy in Task1[56:85]:
            se = hy.text
            Date.append(se)

            
        Task1 = driver.find_elements_by_xpath("//td[@class='column-3']")

        for hy in Task1[56:85]:
            se = hy.text
            Start_up_name.append(se)
            
            
        Task1 = driver.find_elements_by_xpath("//td[@class='column-4']")

        for hy in Task1[56:85]:
            se = hy.text
            Industry.append(se)
            
        Task1 = driver.find_elements_by_xpath("//td[@class='column-5']")

        for hy in Task1[56:85]:
            se = hy.text
            Sub_vertical.append(se)
            
        Task1 = driver.find_elements_by_xpath("//td[@class='column-6']")

        for hy in Task1[56:85]:
            se = hy.text
            city.append(se)
            
        Task1 = driver.find_elements_by_xpath("//td[@class='column-7']")

        for hy in Task1[56:85]:
            se = hy.text
            Invester_name.append(se)
            
        Task1 = driver.find_elements_by_xpath("//td[@class='column-8']")

        for hy in Task1[56:85]:
            se = hy.text
            Investment_type.append(se)
            
        Task1 = driver.find_elements_by_xpath("//td[@class='column-9']")

        for hy in Task1[56:85]:
            se = hy.text
            amount.append(se)

# %%
#Creating and Printing Dataframe
Funding = pd.DataFrame({'Date' : Date, 'Start Up Name':Start_up_name ,'Industry' :Industry ,'Sub vertical' :Sub_vertical ,'City' : city ,'Invester Name' :Invester_name ,'Investment type':Investment_type ,'Amount' : amount })
Funding
# Out:
#           Date              Start Up Name  \
# 0   12/09/2020                  mCaffeine
# 1   09/09/2020                     Qshala
# 2   02/09/2020                      Winzo
# 3   09/09/2020                Hippo Video
# 4   07/09/2020                    Melorra
# 5   07/09/2020                        1mg
# 6   31/08/2020                      mfine
# 7   31/08/2020                       Apna
# 8   03/09/2020                    Railofy
# 9   15/08/2020                     Practo
# 10  13/08/2020                    Medlife
# 11  13/08/2020                  HungerBox
# 12  04/08/2020                      Dunzo
# 13  11/08/2020                   Terra.do
# 14  12/08/2020                  Classplus
# 15  14/08/2020                       Niyo
# 16  10/08/2020                  ZestMoney
# 17  07/08/2020                FreshToHome
# 18  13/08/2020                    Eduvanz
# 19  15/07/2020                   Flipkart
# 20  16/07/2020                    Vedantu
# 21  16/07/2020                       Crio
# 22  14/07/2020                    goDutch
# 23  13/07/2020                   Mystifly
# 24  09/07/2020               JetSynthesys
# 25  10/07/2020                   gigIndia
# 26  15/07/2020                  PumPumPum
# 27  14/07/2020                       FLYX
# 28  13/07/2020  Open Appliances Pvt. Ltd.
#
#                                   Industry  \
# 0                            Personal Care
# 1                                  EduTech
# 2                            Online Gaming
# 3   Video Customer Experience(CX) Platform
# 4                               E-commerce
# 5                               E-commerce
# 6                               HealthTech
# 7                          Human Resources
# 8                           Transportation
# 9                               HealthTech
# 10                              E-commerce
# 11                                FoodTech
# 12                   Hyper-local Logistics
# 13                                 EduTech
# 14                                 EduTech
# 15                                 FinTech
# 16                                 FinTech
# 17                              E-commerce
# 18                                 FinTech
# 19                              E-commerce
# 20                                 EduTech
# 21                                 EduTech
# 22                                 FinTech
# 23                     Airfare Marketplace
# 24                Gaming and Entertainment
# 25                             Marketplace
# 26                       Automotive Rental
# 27                              OTT Player
# 28                  Information Technology
#
#                                          Sub vertical  \
# 0                                 Skincare & Haircare
# 1                  Online Curiosity Platform for Kids
# 2                                       Online Gaming
# 3              Video Customer Experience(CX) Platform
# 4                                Online Jewelry Store
# 5                                     Online Pharmacy
# 6                       On-Demand Healthcare Services
# 7                                Recruitment Platform
# 8                        WL & RAC protection platform
# 9                            Health care and Wellness
# 10                                    Online Pharmacy
# 11                       Online Food Delivery Service
# 12                           Online Delivery Services
# 13                  Online Climate School, E-learning
# 14                        E-learning, Online Tutoring
# 15                                 Financial Services
# 16                                 Financial Services
# 17                                      Food Delivery
# 18                                 Financial Services
# 19                                         E-commerce
# 20                                    Online Tutoring
# 21                   Learning Platform for Developers
# 22                                     Group Payments
# 23  Ticketing, Airline Retailing, and Post-Ticketi...
# 24                           Gaming and Entertainment
# 25                          Crowd Sourcing, Freelance
# 26                          Used Car-leasing platform
# 27                           Streaming Social Network
# 28              Internet-of-Things Security Solutions
#
#                                           City  \
# 0                                       Mumbai
# 1                                    Bangalore
# 2                                    New Delhi
# 3   Newark, Delaware, United States of Amercia
# 4                                    Bangalore
# 5                                      Gurgaon
# 6                                    Bangalore
# 7                                    Bangalore
# 8                                       Mumbai
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                       Stanford, California,
# 14                                       Noida
# 15                                   Bangalore
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                      Mumbai
# 19                                   Bangalore
# 20                                   Bangalore
# 21                                   Bangalore
# 22                                      Mumbai
# 23                     Singapore and Bangalore
# 24                                        Pune
# 25                                        Pune
# 26                                     Gurgaon
# 27                          New York and Delhi
# 28                                   Bangalore
#
#                                         Invester Name         Investment type  \
# 0   Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 1                                  Rainmatter Capital                   Angel
# 2   Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 3   Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 4                          Shadow Holdings, Lightbox.          Debt Financing
# 5          Gaja Capital, Tata Capital, Partners Group             In Progress
# 6                                    Caretech Pte Inc                Series B
# 7          Lightspeed India and Sequoia Capital India                Series A
# 8                                   Chiratae Ventures                    Seed
# 9                                         A1A Company                Series F
# 10         Prasid Uno Family Trust and SC Credit Fund
# 11  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 12                                   Existing Backers             In Progress
# 13  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 14                                        Falcon Edge             In Progress
# 15                                Niyo Solutions Inc.
# 16                            Primrose Hills Ventures
# 17                                     Ascent Capital                 Venture
# 18                              Sequoia India, Unitus                Series A
# 19                                        Walmart Inc                     M&A
# 20                                  Coatue Management                Series D
# 21                                        021 Capital            pre-Series A
# 22  Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 23                                   Recruit Co. Ltd.            pre-Series B
# 24           Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 25       Incubate Fund India and Beyond Next Ventures            pre-Series A
# 26                           Early Adapters Syndicate                    Seed
# 27              Raj Mishra, founder of AIT Global Inc                pre-Seed
# 28                             Unicorn India Ventures  Venture-Series Unknown
#
#              Amount
# 0         3,000,000
# 1           370,000
# 2        15,500,000
# 3         4,500,000
# 4    upto 8,900,000
# 5       100,000,000
# 6         5,400,000
# 7         8,000,000
# 8           950,000
# 9        32,000,000
# 10       23,000,000
# 11        1,560,000
# 12       30,000,000
# 13        1,400,000
# 14  upto 15,000,000
# 15        6,000,000
# 16       10,670,000
# 17       16,200,000
# 18        5,000,000
# 19    1,200,000,000
# 20      100,000,000
# 21          934,160
# 22        1,700,000
# 23        3,300,000
# 24          400,000
# 25          974,200
# 26          292,800
# 27          200,000
# 28          500,000

# %% [markdown]
# # Q.NO.7 Write a program to scrap all the available details of top 10 gaming laptops from digit.in.or Cores”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver = webdriver.Chrome(r"C:\Users\Femina\Downloads\chromedriver_win32\chromedriver.exe ")
#get the web page with given url
url = "https://www.digit.in/"
driver.get(url)
time.sleep(3)
#lets search for best laptop
best_gaming_lap = driver.find_element_by_xpath("//div[@class='listing_container']//ul//li[9]").click()
time.sleep(4)

#lets fetch info of laptops
lap_name = []
op_stm = []
display = []
processor = []
memory = []
weight = []
dimensions = []
graph_processor = []
prices = []
# lets fetch laptop names
name = driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[1]")
for i in name:
    lap_name.append(i.text)
#fetching info related to operating system
try:
    os = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[3]//td[3]")
    for i in os:
        op_stm.append(i.text)
except NoSuchElementException:
    pass
try:
    disp = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[4]//td[3]")
    for i in disp:
        display.append(i.text)
except NoSuchElementException:
    pass
try:
    pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[5]//td[3]")
    for i in pro:
        processor.append(i.text)
except NoSuchElementException:
    pass
try:
    mem = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[6]//td[3]")
    for i in mem:
        memory.append(i.text)
except NoSuchElementException:
    pass
try:
    wgt = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[7]//td[3]")
    for i in wgt:
        weight.append(i.text)
except NoSuchElementException:
    pass
try:
    dim = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[8]//td[3]")
    for i in dim:
        dimensions.append(i.text)
except NoSuchElementException:
    pass
try:
    g_pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[9]//td[3]")
    for i in g_pro:
        graph_processor.append(i.text)
except NoSuchElementException:
    pass
try:
    price = driver.find_elements_by_xpath("//td[@class='smprice']")
    for i in price:
        prices.append(i.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

#creating dataframe
data = list(zip(lap_name,op_stm,display,processor,memory,weight,dimensions,graph_processor,prices))
df = pd.DataFrame(data, columns = ["Laptop Name","Operating System","Display","Processor","Memory","Weight(Kg)","Dimensions","Graphic-Processor","Price"])
df
# Out:
#                 Laptop Name Operating System              Display  \
# 0     Alienware Area 51M R2  Windows 10 Home  17.3" (1920 x 1080)
# 1          Alienware m15 R3  Windows 10 Home  15.6" (3840 x 2160)
# 2    ASUS ROG Strix Scar 15  Windows 10 Home  15.6" (1920 x 1080)
# 3     Asus ROG Zephyrus G14  Windows 10 Home    14" (1920 x 1080)
# 4          Lenovo Legion 5i   Windows 10 Pro  15.6" (1920 x 1080)
# 5  ASUS ROG ZEPHYRUS DUO 15       Windows 10  15.6" (3840 x 1100)
# 6      Acer Aspire 7 gaming  Windows 10 Home  15.6" (1920 x 1080)
#
#                                            Processor                  Memory  \
# 0   10th Generation Intel® Core™ i7-10700 | 2.90 GHz   1 TB SSD/16 GBGB DDR4
# 1       10th Generation Intel® Core™ i9-10980HK | NA   1 TB SSD/16 GBGB DDR4
# 2                      AMD Ryzen™ 9 5900HX | 3.3 GHz   1 TB SSD/16 GBGB DDR4
# 3               AMD 3rd Generation Ryzen 9 | 3.3 GHz   1 TB SSD/16 GBGB DDR4
# 4  10th Generation Intel® Core™ i5-10300H | 2.50 GHz   1 TB SSD/16 GBGB DDR4
# 5                 Intel Core i7 10th Gen 10875H | NA  512 GB SSD/4 GBGB DDR4
# 6                  AMD Ryzen™ 5-5500U hexa-core | NA  512 GB SSD/8 GBGB DDR4
#
#   Weight(Kg)               Dimensions              Graphic-Processor  \
# 0        4.1   27.65 x 402.6 x 319.14        Intel® UHD Graphics 630
# 1         NA                       NA                             NA
# 2       2.30       35.4 x 25.9 x 2.26      NVIDIA® GeForce RTX™ 3070
# 3       1.65        32.5 x 22.1 x 1.8        NVIDIA GeForce RTX 2060
# 4        2.3  363.06 x 259.61 x 23.57  NVIDIA® GeForce® GTX 1650 4GB
# 5        2.4  268.30 x 360.00 x 20.90  NVIDIA GeForce RTX 2070 Max-Q
# 6       2.15       2.29 x 36.3 x 25.4      NVIDIA® GeForce® GTX 1650
#
#        Price
# 0        N/A
# 1  Rs 341990
# 2        N/A
# 3  Rs 164990
# 4   Rs 76988
# 5  Rs 185000
# 6   Rs 64370

# %% [markdown]
# # Q.NO.8 Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver = webdriver.Chrome(r"C:\Users\Femina\Downloads\chromedriver_win32\chromedriver.exe ")
#get the web page with given url
url = "https://www.forbes.com/?sh=55783e032254"
driver.get(url)
time.sleep(3)


#lets get option button from the page
opt_btn = driver.find_element_by_xpath("//div[@class='header__left']//button").click()

#Now select Billionaires from options
blns = driver.find_elements_by_xpath("//li[@data-title='Billionaires']//a[1]")
bln = []
for i in blns[:1]:
    bln.append(i.get_attribute("href"))
     

for i in bln:
    driver.get(i)

bln_list = driver.find_element_by_xpath("//div[@class='channel-special-feature__articles-wrap']//a").click()
time.sleep(8)

#fetch required data from table
#fetching rank
rank = []
try:
    rnk = driver.find_elements_by_xpath("//div[@class='rank']")
    for i in rnk:
        rank.append(i.text)
except NoSuchElementException:
    pass
#fetching names
names = []
try:
    name = driver.find_elements_by_xpath("//div[@class='personName']")
    for i in name:
        names.append(i.text)
except NoSuchElementException:
    pass
#fetching net worth
net_worth = []
try:
    worth = driver.find_elements_by_xpath("//div[@class='netWorth']")
    for i in worth:
        net_worth.append(i.text)
except NoSuchElementException:
    pass
#fetching age
Age = []
try:
    age = driver.find_elements_by_xpath("//div[@class='age']")
    for i in age:
        Age.append(i.text)
except NoSuchElementException:
    Age.append('-')
#fetching citizenship
citizenship = []
try:
    cit = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for i in cit:
        citizenship.append(i.text)
except NoSuchElementException:
    citizenship.append('-')
#fetching source
source = []
try:
    src = driver.find_elements_by_xpath("//div[@class='source-column']")
    for i in src:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
#fetching Industry
industry = []
try:
    ind = driver.find_elements_by_xpath("//div[@class='category']")
    for i in ind:
        industry.append(i.text)
except NoSuchElementException:
    industry.append('-')
    
#creating dataframe
data = list(zip(rank,names,net_worth,Age,citizenship,source,industry))
df = pd.DataFrame(data, columns = ["Rank", "Name", "Net worth", "Age", "Citizenship", "Source","Industry"])
df
# Out:
#      Rank                      Name Net worth Age    Citizenship  \
# 0      1.                Jeff Bezos    $177 B  57  United States
# 1      2.                 Elon Musk    $151 B  49  United States
# 2      3.  Bernard Arnault & family    $150 B  72         France
# 3      4.                Bill Gates    $124 B  65  United States
# 4      5.           Mark Zuckerberg     $97 B  36  United States
# ..    ...                       ...       ...  ..            ...
# 195  195.           Harry Triguboff   $11.2 B  88      Australia
# 196  197.     Leonid Fedun & family   $11.1 B  65         Russia
# 197  197.                 Eyal Ofer   $11.1 B  70         Israel
# 198  197.              Evan Spiegel   $11.1 B  30  United States
# 199  200.     Luis Carlos Sarmiento     $11 B  88       Colombia
#
#                     Source               Industry
# 0                   Amazon             Technology
# 1            Tesla, SpaceX             Automotive
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4                 Facebook             Technology
# ..                     ...                    ...
# 195            real estate            Real Estate
# 196                    oil                 Energy
# 197  real estate, shipping            Diversified
# 198               Snapchat             Technology
# 199                banking  Finance & Investments
#
# [200 rows x 7 columns]

# %% [markdown]
# # Q no 9. program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
driver = webdriver.Chrome(r"C:\Users\Femina\Downloads\chromedriver_win32\chromedriver.exe ")
#get the web page with given url
url = "https://www.youtube.com/"
driver.get(url)
time.sleep(3)

#lets click on a video
clk_video = driver.find_element_by_xpath("/html/body/ytd-app/div/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-rich-grid-renderer/div[6]/ytd-rich-item-renderer[3]/div/ytd-rich-grid-media/div[1]/div/div[1]/h3/a").click()
time.sleep(8)

#Lets scroll the comments

for _ in range(1000):

    driver.execute_script("window.scrollBy(0,100)")

#fetching required data
comments = []
upvotes = []
times = []
try:
    comment = driver.find_elements_by_xpath("//*[@id='content-text']")[:500]
    for i in comment:
        comments.append(i.text)
except NoSuchElementException:
    comments.append('-')
time.sleep(3)

#fetching upvotes
try:
    up = driver.find_elements_by_xpath("//*[@id='vote-count-middle']")[:500]
    for i in up:
        upvotes.append(i.text)
except NoSuchElementException:
    comments.append('-')
    time.sleep(3)

#fetchin time when comment was posted
try:
    tim = driver.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']")[:500]
    for i in tim:
        times.append(i.text.replace('(edited)',''))
except NoSuchElementException:
    times.append('-')
time.sleep(3)

#creating dataframe
data = list(zip(comments,upvotes,times))
df = pd.DataFrame(data, columns = ["Comment","Upvotes","Published time"])
df
# Out:
#                                                Comment Upvotes Published time
# 0    Now a days comment box had been became a bless...      1K   9 months ago
# 1    2% of People who are Reading this comment, I w...    3.4K     1 year ago
# 2    My eyes: It's super easy!\n\nMy brain: Let’s d...     260    1 month ago
# 3    Whoever's reading this,God is about to bless u...      1K     1 year ago
# 4               We all need a sister to do all these 😊     306   8 months ago
# ..                                                 ...     ...            ...
# 347                                       I don't like           8 months ago
# 348                                 Black hair is best             1 week ago
# 349                                              Bye😒😒       2     1 year ago
# 350                                          👎👎👎👎👎👎👎👎👎             4 days ago
# 351                                        It's boring             1 year ago
#
# [352 rows x 3 columns]

# %% [markdown]
# # 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description

# %%
driver = webdriver.Chrome(r"C:\Users\Femina\Downloads\chromedriver_win32\chromedriver.exe ")
# obtaining the web page from the given url
url = "https://www.hostelworld.com/"
driver.get(url)
time.sleep(5)
# now we will find the search bar and search for hostel//s in London location
search_bar = driver.find_element_by_xpath("//input[@id='location-text-input-field']")
search_bar.send_keys('London')

time.sleep(5)
srch_btn = driver.find_element_by_xpath("//button[@id='search-button']").click()

# %%
time.sleep(3)
driver.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2021-08-28&to=2021-08-31&guests=2&page=1")
time.sleep(3)

# %%
#lets find required data
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description =[]
product_url = []
for i in driver.find_elements_by_xpath("//div[@class = 'pagination-item pagination-current' or @class='pagination-item']"):
    i.click()
    time.sleep(4)
    #fetching hostel name
    try:
        name = driver.find_elements_by_xpath("//h2[@class='title title-6']")
        for i in name:
            hostel_name.append(i.text)
    except NoSuchElementException:
        hostel_name.append('-')
    #fetching distance from city centre
    
    try:
        dist = driver.find_elements_by_xpath("//div[@class='subtitle body-3']//a//span[1]")
        for i in dist:
            distance.append(i.text.replace('Hostel - ',''))
    except NoSuchElementException:
        distance.append('-')
        
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
    #fetch privates from price
        try:
            pvt_price = driver.find_element_by_xpath("//a[@class='prices']//div[1]//div")
            pvt_prices.append(pvt_price.text)
        except NoSuchElementException:
            pvt_prices.append('-')
    #fetching dorms from price
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
        try:
            dorms = driver.find_element_by_xpath("//a[@class='prices']//div[2]//div")
            dorms_price.append(dorms.text)
        except NoSuchElementException:
            dorms_price.append('-')
    #fetching facilities
    try:
        fac1 = driver.find_elements_by_xpath("//div[@class='has-wifi']")
        fac2 = driver.find_elements_by_xpath("//div[@class='has-sanitation']")
        for i in fac1:
            for j in fac2:
                facilities.append(i.text +', '+ j.text )
    except NoSuchElementException:
        facilities.append('-')
    #lets fetch url of each hostel
    p_url = driver.find_elements_by_xpath("//div[@class='prices-col']//a[2]")
    for i in p_url:
        product_url.append(i.get_attribute('href'))

for i in product_url:
    driver.get(i)
    time.sleep(3)
    #lets click on show more button for description
    try:
        driver.find_element_by_xpath("//a[@class='toggle-content']").click()
        time.sleep(5)
    except NoSuchElementException:
        pass
    #fetching ratings
    try:
        rat = driver.find_element_by_xpath("//div[@class='score orange big' or @class='score gray big']")
        rating.append(rat.text)
    except NoSuchElementException:
        rating.append('-')
    #fetching total reviews
        
    try:
        rws = driver.find_element_by_xpath("//div[@class='reviews']")
        reviews.append(rws.text.replace('Total Reviews',''))
    except NoSuchElementException:
        reviews.append('-')
    #fetch overall review
    try:
        overall_rw = driver.find_element_by_xpath("//div[@class='keyword']//span")
        over_all.append(overall_rw.text)
    except NoSuchElementException:
        over_all.append('-')
    #fetch property description 
    try:
        disc = driver.find_element_by_xpath("//div[@class='content']")
        description.append(disc.text)
    except NoSuchElementException:
        over_all.append('-')

#creating dataframe
data = list(zip(hostel_name,distance,rating,reviews,over_all,pvt_prices,dorms_price,facilities,description))       
df = pd.DataFrame(data, columns = ["Hostel name","Distance from city centre","ratings","Total reviews","Overall review","Privates from price","Dorms from price","Facilities","Property Description"])
df
# Out:
#                                 Hostel name  \
# 0                    London Waterloo Hostel
# 1                  Barmy Badger Backpackers
# 2           Wombat's The City Hostel London
# 3                   Prime Backpackers Angel
# 4                  St Christopher's Village
# 5      PubLove @ The Steam Engine, Waterloo
# 6            PubLove @ The Crown, Battersea
# 7         Safestay London Elephant & Castle
# 8                      Urbany Hostel London
# 9       PubLove @ The Green Man, Paddington
# 10               PubLove @ The Rose & Crown
# 11                     New Cross Inn Hostel
# 12       St Christopher's Oasis-Female Only
# 13                         Astor Kensington
# 14                         Mapesbury Hostel
# 15                        Hootananny Hostel
# 16                          Astor Hyde Park
# 17                           Phoenix Hostel
# 18       247london Hostel and Private Rooms
# 19                     Burlington Residence
# 20                                 Clink261
# 21                         Generator London
# 22              Smart Russell Square Hostel
# 23              Smart Hyde Park View Hostel
# 24                  Saint James Backpackers
# 25                  Queen Elizabeth Chelsea
# 26               Smart Hyde Park Inn Hostel
# 27                            Pickwick Hall
# 28                      Jaeger Acton Hostel
# 29             No.8 Willesden Hostel London
# 30                      Best London Hostels
# 31                            Atlas Hostels
# 32                   The London Home Hostel
# 33        Le Junction Hostel - Pub & Garden
# 34                       No.8 Seven Sisters
# 35  Safestay London Kensington Holland Park
# 36                            Selina Camden
# 37                           Venture Hostel
# 38       PubLove @ The Exmouth Arms, Euston
# 39                 Kensal Green Backpackers
# 40                       London Backpackers
# 41                 Budget London Apartments
# 42                           Colliers Hotel
# 43                 All Star Private Studios
# 44                      Britannia Inn Hotel
# 45                               Park Hotel
# 46                       Golders Park Hotel
# 47                          Belgravia Hotel
# 48                            Elmwood Hotel
# 49                             Victor Hotel
# 50   Best Western Boltons London Kensington
# 51                         Park Hotel Essex
# 52                          Cranbrook Hotel
# 53                               St. Athans
#
#                      Distance from city centre ratings Total reviews  \
# 0                       0.7km from city centre     7.2         2410
# 1                       5.5km from city centre      10         1653
# 2                       3.6km from city centre     9.2        13146
# 3                       3.6km from city centre      10          513
# 4                       1.8km from city centre     8.9        10830
# 5                       0.5km from city centre     8.8          191
# 6                       4.7km from city centre     5.8          209
# 7                       1.7km from city centre     8.2         3953
# 8                       5.4km from city centre      10          110
# 9                       4.3km from city centre     5.2          392
# 10                      1.6km from city centre     7.4           99
# 11                      6.1km from city centre     7.2         1007
# 12                      1.8km from city centre     9.1          594
# 13                      4.9km from city centre     8.5         6327
# 14                      8.2km from city centre     4.9          357
# 15                        5km from city centre     7.1         1407
# 16                      4.3km from city centre     9.1        11326
# 17                      4.2km from city centre     8.1         3422
# 18                      8.2km from city centre     6.6          443
# 19                      7.1km from city centre     9.8           26
# 20                      3.2km from city centre     8.0         3174
# 21                        3km from city centre     7.6         6739
# 22                      2.6km from city centre     7.5         9504
# 23                        5km from city centre     8.3         4474
# 24                      5.5km from city centre     7.5         1759
# 25                      5.7km from city centre     7.9         3150
# 26                        5km from city centre     7.4         6239
# 27                      2.3km from city centre     9.1         2224
# 28                     10.4km from city centre     8.8          881
# 29                       10km from city centre     8.7         4570
# 30                      8.2km from city centre     6.7          221
# 31                      4.3km from city centre     2.0          194
# 32                      3.6km from city centre     7.7          249
# 33                      9.8km from city centre     6.6          378
# 34                        9km from city centre     7.6         3610
# 35                      5.9km from city centre     8.6         1083
# 36                      5.5km from city centre     9.1            6
# 37                      6.9km from city centre     4.4         1168
# 38                      3.4km from city centre     7.5          979
# 39                      8.2km from city centre     7.0         3601
# 40                     11.9km from city centre     8.5         4117
# 41          Apartment - 8.2km from city centre     6.2          355
# 42              Hotel - 2.1km from city centre     7.7            2
# 43          Apartment - 9.1km from city centre     6.0          150
# 44             Hotel - 14.5km from city centre     9.7           17
# 45              Hotel - 4.9km from city centre       -             -
# 46             Hotel - 10.4km from city centre       -            0
# 47              Hotel - 2.4km from city centre     7.8            7
# 48              Hotel - 3.2km from city centre     7.1          112
# 49              Hotel - 1.8km from city centre       -            0
# 50              Hotel - 5.4km from city centre     2.0            2
# 51             Hotel - 24.1km from city centre       -            0
# 52             Hotel - 14.8km from city centre       -            0
# 53  Bed and Breakfast - 2.9km from city centre       -            0
#
#    Overall review Privates from price Dorms from price  \
# 0       Very Good             Rs14615           Rs1304
# 1          Superb             Rs14615           Rs1304
# 2          Superb             Rs14615           Rs1304
# 3          Superb             Rs14615           Rs1304
# 4        Fabulous             Rs14615           Rs1304
# 5        Fabulous             Rs14615           Rs1304
# 6          Rating             Rs14615           Rs1304
# 7        Fabulous             Rs14615           Rs1304
# 8          Superb             Rs14615           Rs1304
# 9          Rating             Rs14615           Rs1304
# 10      Very Good             Rs14615           Rs1304
# 11      Very Good             Rs14615           Rs1304
# 12         Superb             Rs14615           Rs1304
# 13       Fabulous             Rs14615           Rs1304
# 14         Rating             Rs14615           Rs1304
# 15      Very Good             Rs14615           Rs1304
# 16         Superb             Rs14615           Rs1304
# 17       Fabulous             Rs14615           Rs1304
# 18           Good             Rs14615           Rs1304
# 19         Superb             Rs14615           Rs1304
# 20       Fabulous             Rs14615           Rs1304
# 21      Very Good             Rs14615           Rs1304
# 22      Very Good             Rs14615           Rs1304
# 23       Fabulous             Rs14615           Rs1304
# 24      Very Good             Rs14615           Rs1304
# 25      Very Good             Rs14615           Rs1304
# 26      Very Good             Rs14615           Rs1304
# 27         Superb             Rs14615           Rs1304
# 28       Fabulous             Rs14615           Rs1304
# 29       Fabulous             Rs14615           Rs1304
# 30           Good              Rs3565           Rs1630
# 31         Rating              Rs3565           Rs1630
# 32      Very Good              Rs3565           Rs1630
# 33           Good              Rs3565           Rs1630
# 34      Very Good              Rs3565           Rs1630
# 35       Fabulous              Rs3565           Rs1630
# 36         Superb              Rs3565           Rs1630
# 37         Rating              Rs3565           Rs1630
# 38      Very Good              Rs3565           Rs1630
# 39      Very Good              Rs3565           Rs1630
# 40       Fabulous              Rs3565           Rs1630
# 41           Good              Rs3565           Rs1630
# 42      Very Good              Rs3565           Rs1630
# 43           Good              Rs3565           Rs1630
# 44         Superb              Rs3565           Rs1630
# 45              -              Rs3565           Rs1630
# 46              -              Rs3565           Rs1630
# 47      No Rating              Rs3565           Rs1630
# 48      Very Good              Rs3565           Rs1630
# 49      Very Good              Rs3565           Rs1630
# 50      No Rating              Rs3565           Rs1630
# 51         Rating              Rs3565           Rs1630
# 52      No Rating              Rs3565           Rs1630
# 53      No Rating              Rs3565           Rs1630
#
#                                          Facilities  \
# 0   Free WiFi, Follows Covid-19 sanitation guidance
# 1   Free WiFi, Follows Covid-19 sanitation guidance
# 2   Free WiFi, Follows Covid-19 sanitation guidance
# 3   Free WiFi, Follows Covid-19 sanitation guidance
# 4   Free WiFi, Follows Covid-19 sanitation guidance
# 5   Free WiFi, Follows Covid-19 sanitation guidance
# 6   Free WiFi, Follows Covid-19 sanitation guidance
# 7   Free WiFi, Follows Covid-19 sanitation guidance
# 8   Free WiFi, Follows Covid-19 sanitation guidance
# 9   Free WiFi, Follows Covid-19 sanitation guidance
# 10  Free WiFi, Follows Covid-19 sanitation guidance
# 11  Free WiFi, Follows Covid-19 sanitation guidance
# 12  Free WiFi, Follows Covid-19 sanitation guidance
# 13  Free WiFi, Follows Covid-19 sanitation guidance
# 14  Free WiFi, Follows Covid-19 sanitation guidance
# 15  Free WiFi, Follows Covid-19 sanitation guidance
# 16  Free WiFi, Follows Covid-19 sanitation guidance
# 17  Free WiFi, Follows Covid-19 sanitation guidance
# 18  Free WiFi, Follows Covid-19 sanitation guidance
# 19  Free WiFi, Follows Covid-19 sanitation guidance
# 20  Free WiFi, Follows Covid-19 sanitation guidance
# 21  Free WiFi, Follows Covid-19 sanitation guidance
# 22  Free WiFi, Follows Covid-19 sanitation guidance
# 23  Free WiFi, Follows Covid-19 sanitation guidance
# 24  Free WiFi, Follows Covid-19 sanitation guidance
# 25  Free WiFi, Follows Covid-19 sanitation guidance
# 26  Free WiFi, Follows Covid-19 sanitation guidance
# 27  Free WiFi, Follows Covid-19 sanitation guidance
# 28  Free WiFi, Follows Covid-19 sanitation guidance
# 29  Free WiFi, Follows Covid-19 sanitation guidance
# 30  Free WiFi, Follows Covid-19 sanitation guidance
# 31  Free WiFi, Follows Covid-19 sanitation guidance
# 32  Free WiFi, Follows Covid-19 sanitation guidance
# 33  Free WiFi, Follows Covid-19 sanitation guidance
# 34  Free WiFi, Follows Covid-19 sanitation guidance
# 35  Free WiFi, Follows Covid-19 sanitation guidance
# 36  Free WiFi, Follows Covid-19 sanitation guidance
# 37  Free WiFi, Follows Covid-19 sanitation guidance
# 38  Free WiFi, Follows Covid-19 sanitation guidance
# 39  Free WiFi, Follows Covid-19 sanitation guidance
# 40  Free WiFi, Follows Covid-19 sanitation guidance
# 41  Free WiFi, Follows Covid-19 sanitation guidance
# 42  Free WiFi, Follows Covid-19 sanitation guidance
# 43  Free WiFi, Follows Covid-19 sanitation guidance
# 44  Free WiFi, Follows Covid-19 sanitation guidance
# 45  Free WiFi, Follows Covid-19 sanitation guidance
# 46  Free WiFi, Follows Covid-19 sanitation guidance
# 47  Free WiFi, Follows Covid-19 sanitation guidance
# 48  Free WiFi, Follows Covid-19 sanitation guidance
# 49  Free WiFi, Follows Covid-19 sanitation guidance
# 50  Free WiFi, Follows Covid-19 sanitation guidance
# 51  Free WiFi, Follows Covid-19 sanitation guidance
# 52  Free WiFi, Follows Covid-19 sanitation guidance
# 53  Free WiFi, Follows Covid-19 sanitation guidance
#
#                                  Property Description
# 0            73 Lambeth Walk, London, London, England
# 1     17 Longridge Road, Earls Court, London, England
# 2                      7 Dock Street, London, England
# 3       333 City Road, 333 City Road, London, England
# 4            165 Borough High Street, London, England
# 5                    41-42 Cosser St, London, England
# 6      102 Lavender Hill,, Battersea, London, England
# 7              144-152 Walworth Road, London, England
# 8   48-49 Princes Square, Paddington, London, England
# 9                   308 Edgware Road, London, England
# 10                   65 Union Street, London, England
# 11                323 New Cross Road, London, England
# 12  163 Borough High Street, SE1 1HR, Southwark, L...
# 13  45 Queensborough Terrace, Bayswater, London, E...
# 14                39 Chatsworth Road, London, England
# 15            95 Effra Road, Brixton, London, England
# 16  191 Queensgate, South Kensington, London, England
# 17                 6 Daventry Street, London, England
# 18         37 Chatworth Road, London, London, England
# 19  Lord Annaly House 146A Bedford Hill, London, E...
# 20  261-265 Grays Inn Road, Kings Cross, London, E...
# 21  Compton Place, Off 37 Tavistock Place, WC1, Lo...
# 22                71 Guilford Street, London, England
# 23        16 Leinster Terrace W2 3EU, London, England
# 24                 21 Longridge Road, London, England
# 25                   58 Bagleys Lane, London, England
# 26  48 - 50 Inverness Terrace, Bayswater, London, ...
# 27       7 Bedford Place, Bloomsbury, London, England
# 28      50, Acton High street, Acton, London, England
# 29            305 High Rd, Willesden, London, England
# 30                       22 Anson Rd, London, England
# 31      16 Talbot Square, Paddington, London, England
# 32        39 Chatsworth Road, London, London, England
# 33                   47 Station road, London, England
# 34  618 Seven Sisters Rd, Seven Sisters, London, E...
# 35    Holland Park Ave, Holland Walk, London, England
# 36      89 Chalk Farm Rd, Chalk Farm, London, England
# 37        86 Tanner's Hill, Deptford, London, England
# 38                1 Starcross Street, London, England
# 39                   639 Harrow Road, London, England
# 40  8/10 Queens Parade, Queens Road, Hendon Centra...
# 41  30 Chatsworth Rd., Willesden Green, London, En...
# 42        95-97 Warwick Way, Pimlico, London, England
# 43                   Willesden Green, London, England
# 44  54, Mansfield Road, Ilford London, London, Eng...
# 45            175 Golders Green Road, London, England
# 46                  104 Ebury Street, London, England
# 47     19 & 20 Argyle square, London, London, England
# 48        51 Belgrave Road, Victoria, London, England
# 49               19-21 Penywern Road, London, England
# 50        327 Cranbrook Road, Ilford, London, England
# 51       22/24 Coventry Road, Ilford, London, England
# 52  20 Tavistock Place, Russell Square, London, En...
# 53                   27 South Ealing, London, England
